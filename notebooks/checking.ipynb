# %%
import sys
import os
sys.path.append(os.path.abspath(".."))
from tools.record import RedisFillLoader

# %%
tgf = RedisFillLoader('2025,5,1','2025,5,8','capital_proton_tgf')

# %%
tgf.get_concat_df()
# Out:
# Concatenating fills: 100%|██████████| 8/8 [00:00<00:00, 20.16it/s]
#                         time                ts                  instr  \
# 0 2025-05-02 10:00:13.363765  1746151213363765  FUT_TAIFEX_TGF:202508
# 1 2025-05-02 10:00:13.364527  1746151213364527  FUT_TAIFEX_TGF:202506
# 2 2025-05-02 10:00:18.364071  1746151218364071  FUT_TAIFEX_TGF:202506
# 3 2025-05-02 10:01:07.028055  1746151267028055  FUT_TAIFEX_TGF:202508
# 4 2025-05-02 13:47:19.970144  1746164839970144  FUT_TAIFEX_TGF:202506
# 5 2025-05-02 14:14:45.120566  1746166485120566  FUT_TAIFEX_TGF:202506
# 6 2025-05-05 10:54:18.646587  1746413658646587  FUT_TAIFEX_TGF:202506
# 7 2025-05-05 12:07:12.345308  1746418032345308  FUT_TAIFEX_TGF:202506
# 8 2025-05-05 12:07:12.345914  1746418032345914  FUT_TAIFEX_TGF:202506
# 9 2025-05-05 12:12:42.811340  1746418362811340  FUT_TAIFEX_TGF:202506
#
#      oflag               tid       px alqortake  sz     theo      fwd  ...  \
# ...

# %%
tgf.print_pnl_summary()
# Out:
# instr                    realized_pnl    net_position
# FUT_TAIFEX_TGF:202506         -223450               0
# FUT_TAIFEX_TGF:202508            -950               0
